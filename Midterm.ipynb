# %% [markdown]
# # Midterm

# %% [markdown]
# # Q1. 畫出 Diamond Shape

# %%
def diamond(n):
    for i in range(n):
        print(" "*(n-i)+"╬"*(1+2*i))
    for i in range(n,-1,-1):
        print(" "*(n-i)+"╬"*(1+2*i))

# %%
diamond(5)
# Out:
#      ╬
#     ╬╬╬
#    ╬╬╬╬╬
#   ╬╬╬╬╬╬╬
#  ╬╬╬╬╬╬╬╬╬
# ╬╬╬╬╬╬╬╬╬╬╬
#  ╬╬╬╬╬╬╬╬╬
#   ╬╬╬╬╬╬╬
#    ╬╬╬╬╬
#     ╬╬╬
#      ╬

# %% [markdown]
# # Q2.  刪除重複性的資料

# %%
symbols01 = open("symbols01.txt", "r", encoding="UTF-8").read().split('\n')

# %%
symbols02 = open("symbols02.txt", "r", encoding="UTF-8").read().split('\n')

# %%
symbols03 = list(set(symbols01) | set(symbols02))

# %%
with open('symbols03.txt','w') as f:
    for symbol in symbols03:
        f.write(symbol.strip().upper() + "\n")

# %% [markdown]
# # Q3. 下載台灣上市公司基本資料

# %%
import pandas as pd
import io 
import requests

# %%
r = requests.get("http://dts.twse.com.tw/opendata/t187ap03_L.csv")

# %%
r.encoding = "big5"

# %%
pd.read_csv(io.StringIO(r.text), index_col=False, skiprows=1)
# Out:
#          公司代號              公司名稱       產業別  \
# 0        1101        台灣水泥股份有限公司      水泥工業
# 1        1102        亞洲水泥股份有限公司      水泥工業
# 2        1103        嘉新水泥股份有限公司      水泥工業
# 3        1104        環球水泥股份有限公司      水泥工業
# 4        1108        幸福水泥股份有限公司      水泥工業
# 5        1109        信大水泥股份有限公司      水泥工業
# 6        1110        東南水泥股份有限公司      水泥工業
# 7        1201      味全食品工業股份有限公司      食品工業
# 8        1203          味王股份有限公司      食品工業
# 9        1210      大成長城企業股份有限公司      食品工業
# 10       1213       大西洋飲料股份有限公司      食品工業
# 11       1215      台灣卜蜂企業股份有限公司      食品工業
# 12       1216        統一企業股份有限公司      食品工業
# 13       1217         愛之味股份有限公司      食品工業
# 14       1218        泰山企業股份有限公司      食品工業
# 15       1219        福壽實業股份有限公司      食品工業
# 16       1220        台榮產業股份有限公司      食品工業
# 17       1225        福懋油脂股份有限公司      食品工業
# 18       1227        佳格食品股份有限公司      食品工業
# 19       1229        聯華實業股份有限公司      食品工業
# 20       1231      聯華食品工業股份有限公司      食品工業
# 21       1232         大統益股份有限公司      食品工業
# 22       1233        天仁茶業股份有限公司      食品工業
# 23       1234          黑松股份有限公司      食品工業
# 24       1235        興泰實業股份有限公司      食品工業
# 25       1236        宏亞食品股份有限公司      食品工業
# 26       1256        鮮活控股股份有限公司      食品工業
# 27       1262          綠悅控股有限公司        其他
# 28       1301      台灣塑膠工業股份有限公司      塑膠工業
# 29       1303      南亞塑膠工業股份有限公司      塑膠工業
# ..        ...               ...       ...
# 893      9912        偉聯科技股份有限公司  電腦及週邊設備業
# 894      9914       美利達工業股份有限公司        其他
# 895      9917        中興保全股份有限公司        其他
# 896      9918       欣欣天然氣股份有限公司     油電燃氣業
# 897      9919       康那香企業股份有限公司        其他
# 919  12F, No.30,sec.3,Bode  RD.Songshan District.,T...      2570-6985
# 920     No.12,Rung-Kung S. STTao-Yuan 328, Taiwan,ROC　   (03)473-5259
# 921  No.1119,Sec.1,Zhongshan Rd.,Guanyin Shiang,Tao...     03-4738325
# 922                                                NaN            NaN
#
#                                             電子郵件信箱  \
# 0                         finance@taiwancement.com
# 1                               service@acc.com.tw
# 2               investor-relations@chcgroup.com.tw
# 3                                    ucc@ucctw.com
# 4                            wendy@luckygrp,com.tw
# 5                           service@hsingta.com.tw
# 6                           southeast@secement.com
# 7                          service@weichuan.com.tw
# 8                                wei@vewong.com.tw
# 9                         john@greatwall-group.com
# 10                         c5012903@ms23.hinet.net
# 11                            service@cptwn.com.tw
# 12                           jlian@mail.pec.com.tw
# 13                          a11369@mail.agv.com.tw
# 14                           taisun1@taisun.com.tw
# 15                            fwusow@fwusow.com.tw
# 16                         glen6572@tairoun.com.tw
# 17                         cherry.lin@fopco.com.tw
# 18                   spokesperson1@sfworldwide.com
# 19                                info@lhic.com.tw
# 20                           tomlin@lianhwa.com.tw
# 21                        finance@mail.ttet.com.tw
# 22                         chafortea@tenren.com.tw
# 23                          heysong@heysong.com.tw
# 24                         shintai1235@seed.net.tw
# 25                                    hunya.com.tw
# 26                              XH@sunjuice.com.cn
# 27                 bonnie.tsai@greenseal-group.com
# 28                              formosa@fpc.com.tw
# 29                                nanya@npc.com.tw
# ..                                             ...
# 893                                              N
# 894                          bicycle@merida.com.tw
# 895                        CHENSHUFEN@SECOM.COM.TW
# 896                        ssngasll@ms67.hinet.net
# 897                    christine.wu@knh-global.com
# 898                          Sandylin@giant.com.tw
# 899                         stephen@fuhsing.com.tw
# 900  TSUNGHSIEN.WENG@SKS.COM.TW;0086996@sks.com.tw
# 901                      service@shinhaigas.com.tw
# 902                         financial@tmicl.com.tw
# 903                     091002@mail.chinatv.com.tw
# 904                       job@choicecompany.com.tw
# 905                                 avo@chc.com.tw
# 906                      hsinkao.gas@msa.hinet.net
# 907                         karencheng@ctci.com.tw
# 908                                              -
# 909                             ping@chingfeng.com
# 910                            peggy@npcgas.com.tw
# 911                              finance@paiho.com
# 912                     emily@mail.honchuan.com.tw
# 913                           S209311@SINYI.COM.TW
# 914                            may.liao@tac.com.tw
# 915                          simon@mail.nak.com.tw
# 916                              ir@holiday.com.tw
# 917                      fisher.chen@shinih.com.tw
# 918                        cmc@mail.ruentex.com.tw
# 919                          contact@sanfar.com.tw
# 920                            service@sdti.com.tw
# 921                      ct.service@century.com.tw
# 922                                            NaN
#
#                                  網址
# 0        http://www.taiwancement.com
# 1                     www.acc.com.tw
# 2                www.chcgroup.com.tw
# 3                      www.ucctw.com
# 4                www.luckygrp.com.tw
# 5                 www.hsingta.com.tw
# 6         www.southeastcement.com.tw
# 7         http://www.weichuan.com.tw
# 8              http://www.vewong.com
# 9              http://www.dachan.com
# 10      http://www.applesidra.com.tw
# 11           http://www.cptwn.com.tw
# 12   http://www.uni-president.com.tw
# 13                    www.agv.com.tw
# 14                 www.taisun.com.tw
# 15                 www.fwusow.com.tw
# 16        http://www.tairoun.com.tw/
# 17                  WWW.FOPCO.COM.TW
# 18       http://www.sfworldwide.com/
# 19            http://www.lhic.com.tw
# 20                www.lianhwa.com.tw
# 21            http://www.ttet.com.tw
# 22         http://www.tenren.com.tw/
# 23                www.heysong.com.tw
# 24           www.shintai-feed.com.tw
# 25                  www.hunya.com.tw
# 26       http://www.myfreshjuice.com
# 27           www.greenseal-group.com
# 28             http://www.fpc.com.tw
# 29             http://www.npc.com.tw
# ..                               ...
# 893          http://www.agneovo.com/
# 894                www.merida.com.tw
# 895                 WWW.SECOM.COM.TW
# 896    http://www.shinshingas.com.tw
# 897   http://www.knh.com.tw/main.php
# 898    http://www.giant-bicycles.com
# 899               www.fuhsing.com.tw
# 900                   www.sks.com.tw
# 901    http://www.shinhaigas.com.tw/
# 902                 www.tmicl.com.tw
# 903                   www.ctv.com.tw
# 904  http://www.choicecompany.com.tw
# 905                   www.chc.com.tw
# 906                 www.hkgas.com.tw
# 907                  www.ctci.com.tw
# 908               www.globeunion.com
# 909         http://www.chingfeng.com
# 910         http://www.npcgas.com.tw
# 911             http://www.paiho.com
# 912       http://www.honchuan.com.tw
# 913                 WWW.SINYI.COM.TW
# 914            http://www.tac.com.tw
# 915                   www.nak.com.tw
# 916               www.holiday.com.tw
# 917                www.shinih.com.tw
# 918            www.rt-develop.com.tw
# 919          www.sanfarproperty.com/
# 920                  www.sdti.com.tw
# 921               www.century.com.tw
# 922                              NaN
#
# [923 rows x 26 columns]

# %% [markdown]
# # Q4. 畫出技術曲線

# %%
import pandas_datareader.data as web
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
stock = web.DataReader('1101.tw', "yahoo", datetime(2016, 1, 1))

# %%
stock.head()
# Out:
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2016-01-04  27.299999  27.299999  26.150000  26.150000  24.138956  10418000.0
# 2016-01-05  26.150000  26.700001  26.100000  26.400000  24.369730   5369000.0
# 2016-01-06  26.450001  26.549999  26.000000  26.049999  24.046646   5148000.0
# 2016-01-07  26.299999  27.600000  26.250000  27.350000  25.246670  20251000.0
# 2016-01-08  27.250000  27.299999  26.700001  27.000000  24.923586  11895000.0

# %%
# MACD：對長期與短期的移動平均線 收斂或發散的徵兆，加以雙重平滑處理，用來判斷買賣股票的時機與訊號(確定波段漲幅 找到買賣點)
stock['EMAfast'] = pd.Series.ewm(stock['Close'], span = 12).mean()
stock['EMAslow'] = pd.Series.ewm(stock['Close'], span = 26).mean()
stock['DIF'] = (stock['EMAfast'] - stock['EMAslow'])
stock['MACD'] = pd.Series.ewm(stock['DIF'], span = 9).mean()

# %%
stock.head()
# Out:
#                  Open       High        Low      Close  Adj Close      Volume  \
# Date
# 2016-01-04  27.299999  27.299999  26.150000  26.150000  24.138956  10418000.0
# 2016-01-05  26.150000  26.700001  26.100000  26.400000  24.369730   5369000.0
# 2016-01-06  26.450001  26.549999  26.000000  26.049999  24.046646   5148000.0
# 2016-01-07  26.299999  27.600000  26.250000  27.350000  25.246670  20251000.0
# 2016-01-08  27.250000  27.299999  26.700001  27.000000  24.923586  11895000.0
#
#               EMAfast    EMAslow       DIF      MACD
# Date
# 2016-01-04  26.150000  26.150000  0.000000  0.000000
# 2016-01-05  26.285417  26.279808  0.005609  0.003116
# 2016-01-06  26.193533  26.197240 -0.003707  0.000320
# 2016-01-07  26.558585  26.519501  0.039083  0.013451
# 2016-01-08  26.678516  26.630931  0.047585  0.023605

# %%
plt.subplot(2,1,1)
stock[['Close']].plot(legend='best', figsize=(10,8),ax=plt.gca())
plt.subplot(2,1,2)
stock['DIF'].plot(legend='best', figsize=(10,8),ax=plt.gca())
stock['MACD'].plot(legend='best', figsize=(10,8),ax=plt.gca())

# %% [markdown]
# # Q5. 策略回測

# %%
import ffn
import pandas as pd
import pandas_datareader.data as web
import pickle
from datetime import datetime
import numpy as np
import math as m

# %%
import talib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-9bc7b4202a1f> in <module>()
# ----> 1 import talib
#
# ModuleNotFoundError: No module named 'talib'

# %%
with open("stockdata","rb") as f:
    data = pickle.load(file=f)

# %%
# 計算 MaxDD
def DrawDownAnalysis(cumRet):
    dd_series = ffn.core.to_drawdown_series(cumRet)
    dd_details = ffn.core.drawdown_details(dd_series)
    return dd_details['drawdown'].min(), dd_details['days'].max()

# %%
# 利用策略產生的持有部位資訊，計算底下四個指標來判斷投資績效
# sharpe ratio: 判斷報酬的好壞跟穩定度，數值越大越好
# maxdd: maximum drawdown, 最糟糕的狀況會賠幾 %
# maxddd: maximum drawdown duration, 低於上一次最高報酬的天數
# cumRet[-1]: 最後賺的 % 數

def indicators(df):
    dailyRet = df['Close'].pct_change()
    excessRet = (dailyRet - 0.04/252)[df['positions'] == 1]
    SharpeRatio = np.sqrt(252.0)*np.mean(excessRet)/np.std(excessRet)
    
    cumRet = np.cumprod(1+excessRet)
    
    maxdd, maxddd = DrawDownAnalysis(cumRet)
    
    return SharpeRatio, maxdd, maxddd, cumRet[-1]

# %%
# 這是我們的策略的部分
# 主要只是要算出進出的訊號 signals 跟何時持有部位 positions
# 底下是一個突破系統的範例

def Breakout_strategy(df):
    # Donchian Channel
    df['20d_high'] = np.round(pd.Series.rolling(df['Close'], window=20).max(), 2)
    df['10d_low'] = np.round(pd.Series.rolling(df['Close'], window=10).min(), 2)

    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['Close'][t] > df['20d_high'][t-1]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['Close'][t] < df['10d_low'][t-1]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def RSI_7030_strategy(df):
    df['RSI'] = talib.RSI(df['Close'].values)
    
    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['RSI'][t-1] < 30:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['RSI'][t-1] > 70:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def BBands_strategy(df):
    df['UBB'], df['MBB'], df['LBB'] = talib.BBANDS(df['Close'].values, matype=MA_Type.T3)

    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['Close'][t] < df['LBB'][t-1]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['Close'][t] > df['UBB'][t-1]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False

    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
# MACD：快線 (DIF) 向上突破 慢線 (MACD)。 → 買進訊號 
#       快線 (DIF) 向下跌破 慢線 (MACD)。→ 賣出訊號

def M054030032_strategy(df):
    df['EMAfast'] = pd.Series.ewm(df['Close'], span = 12).mean()
    df['EMAslow'] = pd.Series.ewm(df['Close'], span = 26).mean()
    df['DIF'] = (df['EMAfast'] - df['EMAslow'])
    df['MACD'] = pd.Series.ewm(df['DIF'], span = 9).mean()
    
    has_position = False
    df['signals'] = 0
    for t in range(2, df['signals'].size):
        if df['DIF'][t-1]<df['MACD'][t] and df['DIF'][t]>df['MACD'][t]:
            if not has_position:
                df.loc[df.index[t], 'signals'] = 1
                has_position = True
        elif df['DIF'][t-1]>df['MACD'][t] and df['DIF'][t]<df['MACD'][t]:
            if has_position:
                df.loc[df.index[t], 'signals'] = -1
                has_position = False
    
    df['positions'] = df['signals'].cumsum().shift()
    return df

# %%
def apply_strategy(strategy, df):
    return strategy(df)

# %%
# 計算各支股票的回測結果
results = []

#strategies = [Breakout_strategy, RSI_7030_strategy, BBands_strategy, 學號_strategy]
strategies = [Breakout_strategy, RSI_7030_strategy, BBands_strategy,M054030032_strategy]

for symbol in data:
    for strategy in strategies:
        try:
            apply_strategy(strategy, data[symbol])
            if np.all(data[symbol]['signals']==0):
                print("Symbol:", symbol, "使用", strategy.__name__, "策略沒有出現買賣訊號。")
                continue
            SharpeRatio, maxdd, maxddd, finalRet = indicators(data[symbol])
            days = (data[symbol].index[-1] - data[symbol].index[0]).days
            results.append((SharpeRatio, maxdd, maxddd, finalRet, days,
                            data[symbol][data[symbol]['signals'] > 0]['signals'].sum(), symbol, strategy.__name__))
        except Exception as e:
            print("Error occurs at symbol:", symbol, "Strategy:", strategy.__name__, "==>", e.args)
# Out:
# Error occurs at symbol: TICC Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: TICC Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: TWIN Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: TWIN Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: AMOT Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: AMOT Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: CDZI Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: CDZI Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: GOOG Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: GOOG Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: TBNK Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: TBNK Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: RICK Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: RICK Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: UTMD Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: UTMD Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: YTRA Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: YTRA Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: CSML Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: CSML Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: NLNK Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: NLNK Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: BLCM Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: BLCM Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: CZNC Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: CZNC Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: GERN Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: GERN Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: CDXS Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: CDXS Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: TTPH Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: TTPH Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: SCAC Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: SCAC Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: HBCP Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: HBCP Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: LCA Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: LCA Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: BBGI Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: BBGI Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: TCRD Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: TCRD Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: TSLA Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: TSLA Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: ISRL Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: ISRL Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: BELFB Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: BELFB Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: PSC Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: PSC Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: NKSH Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: NKSH Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: VRA Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: VRA Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: NEWT Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: NEWT Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: AAPL Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: AAPL Strategy: BBands_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: DFRG Strategy: RSI_7030_strategy ==> ("name 'talib' is not defined",)
# Error occurs at symbol: DFRG Strategy: BBands_strategy ==> ("name 'talib' is not defined",)

# %%
results_df = pd.DataFrame(results, columns=['sharpe','MaxDrawDown','MaxDrawDownDuration','returns', 
                                            'days', 'entries','symbol','strategy'])

# %%
results_df.head()
# Out:
#      sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries symbol  \
# 0  0.131503    -0.208296                  281  0.995734   705       11   TICC
# 1  0.495801    -0.281448                  281  1.106852   705       19   TICC
# 2  1.365570    -0.361485                  299  1.631388   705       12   TWIN
# 3  1.933545    -0.294449                  312  2.424139   705       19   TWIN
# 4 -0.031885    -0.316309                  633  0.922493   705       13   AMOT
#
#               strategy
# 0    Breakout_strategy
# 1  M054030032_strategy
# 2    Breakout_strategy
# 3  M054030032_strategy
# 4    Breakout_strategy

# %%
results_df.sort_values('MaxDrawDown',ascending=False).head()
# Out:
#       sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries  \
# 18  3.040178    -0.023844                   58  1.073352   203        3
# 19  2.641215    -0.039218                   96  1.097648   203        7
# 36 -1.211961    -0.057928                  240  0.957529   473        6
# 32 -5.121414    -0.061511                  164  0.940172   384        4
# 49  0.447612    -0.081960                  382  1.027462   438       13
#
#    symbol             strategy
# 18   CSML    Breakout_strategy
# 19   CSML  M054030032_strategy
# 36    LCA    Breakout_strategy
# 32   SCAC    Breakout_strategy
# 49    PSC  M054030032_strategy

# %%
results_df.sort_values('returns',ascending=False).head()
# Out:
#       sharpe  MaxDrawDown  MaxDrawDownDuration   returns  days  entries  \
# 3   1.933545    -0.294449                  312  2.424139   705       19
# 13  2.269524    -0.122143                  164  1.931088   705       16
# 43  1.784041    -0.186782                  209  1.668614   705       18
# 57  2.709350    -0.085443                  121  1.653780   705       13
# 2   1.365570    -0.361485                  299  1.631388   705       12
#
#    symbol             strategy
# 3    TWIN  M054030032_strategy
# 13   RICK  M054030032_strategy
# 43   TSLA  M054030032_strategy
# 57   AAPL  M054030032_strategy
# 2    TWIN    Breakout_strategy
